# %% [markdown]
# <a href="https://colab.research.google.com/github/Mogatala8374/MCU-Marvel-Media-Complete-Dataset/blob/main/MCU_%26_Marvel_Media_%E2%80%94_Complete_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -**   Mogatala Yuvaraju

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.
#
# # Project Summary
#
# This project focuses on the **Exploratory Data Analysis (EDA) of the Marvel Cast Dataset** using Python. The primary objective of the project is to analyze the dataset, understand its structure, identify meaningful patterns, and visualize important insights related to Marvel movies and their cast members. Exploratory Data Analysis is an essential step in the data analysis process because it helps in understanding the characteristics of a dataset before applying advanced statistical or machine learning techniques.
#
# The project was implemented using four Python libraries: **Pandas**, **NumPy**, **Matplotlib**, and **Seaborn**. Pandas was used for loading, cleaning, filtering, and manipulating the dataset efficiently. NumPy was utilized for numerical operations and handling mathematical computations. Matplotlib was used to create basic visualizations, while Seaborn was employed to generate attractive and informative statistical plots. These libraries together provide a comprehensive environment for performing data analysis and visualization.
#
# The Marvel Cast Dataset contains information about Marvel movies, their release years, actor names, character names, cast order, popularity scores, and other related details. The analysis began with importing the dataset into a Pandas DataFrame, followed by examining its shape, data types, column names, and descriptive statistics. Missing values and duplicate records were identified and handled appropriately to improve the quality of the dataset. Data cleaning ensures that the analysis is accurate and reliable.
#
# The analysis revealed several interesting insights. Some Marvel movies have significantly larger casts than others, indicating the presence of ensemble films featuring multiple superheroes. A small number of actors appear repeatedly across different movies, reflecting long-term character portrayals within the Marvel Cinematic Universe. The popularity scores exhibit a positively skewed distribution, with only a few actors achieving exceptionally high popularity. Additionally, lead actors generally have lower cast order values, while supporting actors appear later in the cast list. The study also indicates that recent Marvel productions tend to feature larger casts and more diverse characters.
#
# Overall, this project demonstrates how Exploratory Data Analysis can transform raw data into meaningful information. By applying data cleaning, statistical analysis, and visualization techniques, the project provides a comprehensive understanding of the Marvel Cast Dataset. It also highlights the importance of EDA in identifying trends, patterns, and relationships that can support future predictive modeling and decision-making. The project serves as an excellent practical application of Python programming and data analysis concepts and provides a strong foundation for further studies in data science and machine learning.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.
#
# https://github.com/Mogatala8374/MCU-Marvel-Media-Complete-Dataset

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ## Problem Statement: Analyzing the Marvel Cinematic Universe Cast Dataset
#
# This project aims to conduct an in-depth Exploratory Data Analysis (EDA) on a dataset containing information about the cast of Marvel Cinematic Universe (MCU) productions. The primary objective is to uncover patterns, trends, and relationships within the data to gain a comprehensive understanding of the actors, their roles, and their popularity within the MCU.
#
# Specifically, the analysis will address the following key questions:
#
# 1.  **Distribution of Movies Over Time:** How has the production of Marvel movies changed over the years? Are there specific periods of high activity or growth?
# 2.  **Key Actors and Characters:** Who are the most frequently appearing actors and characters in the MCU? What does this imply about their centrality to the franchise?
# 3.  **Actor Popularity Insights:** What is the distribution of actor popularity scores? Are there a few highly popular actors, or is popularity more evenly distributed? How does `cast_order` relate to an actor's `popularity`?
# 4.  **Relationships Between Variables:** Are there correlations between `popularity` and other numerical variables like `cast_order` or `year`? How do categorical variables (e.g., `title`, `character`) influence these relationships?
# 5.  **Missing Data Impact:** How does the presence of missing values in `character` and `profile_path` affect the analysis, and how can these be effectively handled?
#
# By answering these questions, this EDA will provide valuable insights into the dynamics of the MCU cast, which can inform business decisions related to casting, marketing strategies, and franchise development.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

path = '/content/drive/MyDrive/Colab Notebooks/marvel_cast.csv'
df = pd.read_csv(path)
df.head()
# Out:
#              title  year  tmdb_id          actor_name  \
# 0  Captain America  1944   106355        Dick Purcell
# 1  Captain America  1944   106355          Lorna Gray
# 2  Captain America  1944   106355       Lionel Atwill
# 3  Captain America  1944   106355  Charles Trowbridge
# 4  Captain America  1944   106355       Russell Hicks
#
#                          character  cast_order  actor_tmdb_id  popularity  \
# 0  Captain America / Grant Gardner           0          13970      0.3970
# 1                    Gail Richards           1          96719      0.4055
# 2                     Cyrus Maldor           2           2495      0.4445
# 3       Police Commissioner Dryden           3          96721      0.3023
# 4                   Mayor Randolph           4          13969      0.8038
#
#                                         profile_path
# 0  https://image.tmdb.org/t/p/w185/p0RZAW7uh1dIwu...
# 1  https://image.tmdb.org/t/p/w185/cdWxxF7weiJucc...
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (1628, 9)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1628 entries, 0 to 1627
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          1628 non-null   object
#  1   year           1628 non-null   int64
#  2   tmdb_id        1628 non-null   int64
#  3   actor_name     1628 non-null   object
#  4   character      1618 non-null   object
#  5   cast_order     1628 non-null   int64
#  6   actor_tmdb_id  1628 non-null   int64
#  7   popularity     1628 non-null   float64
#  8   profile_path   1538 non-null   object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 114.6+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().value_counts()
# Out:
# False    1628
# Name: count, dtype: int64

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# title             0
# year              0
# tmdb_id           0
# actor_name        0
# character        10
# cast_order        0
# actor_tmdb_id     0
# popularity        0
# profile_path     90
# dtype: int64

# %%
# Visualizing the missing values

plt.figure(figsize=(8,4))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['title', 'year', 'tmdb_id', 'actor_name', 'character', 'cast_order',
#        'actor_tmdb_id', 'popularity', 'profile_path'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#               year       tmdb_id   cast_order  actor_tmdb_id   popularity
# count  1628.000000  1.628000e+03  1628.000000   1.628000e+03  1628.000000
# mean   2010.861794  3.162634e+05     6.820639   4.945436e+05     1.800077
# std      14.396141  3.389440e+05     4.312303   8.378645e+05     1.650342
# min    1944.000000  5.570000e+02     0.000000   3.000000e+00     0.000000
# 25%    2005.000000  2.746000e+04     3.000000   1.296925e+04     0.529900
# 50%    2016.000000  2.259250e+05     7.000000   6.543400e+04     1.320000
# 75%    2022.000000  4.976980e+05    11.000000   9.594120e+05     2.724875
# max    2026.000000  1.387507e+06    14.000000   6.100886e+06    10.553100

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# title             106
# year               36
# tmdb_id           113
# actor_name       1149
# character        1188
# cast_order         15
# actor_tmdb_id    1149
# popularity       1218
# profile_path     1067
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

missing_values = df.isnull().sum()
missing_percentage = (missing_values / len(df)) * 100
missing_df = pd.DataFrame({'Missing Count': missing_values, 'Missing Percentage': missing_percentage})

display(missing_df[missing_df['Missing Count'] > 0])
# Out:
#               Missing Count  Missing Percentage
# character                10            0.614251
# profile_path             90            5.528256

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

plt.figure(figsize=(12,5))
sns.countplot(data=df,x='year',order=sorted(df['year'].unique()))
plt.xticks(rotation=90)
plt.title("Marvel Movies by Year")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# A histogram was chosen to visualize the distribution of movie release years. This chart type is excellent for showing the frequency of numerical data within specified bins, making it easy to identify periods with higher or lower movie production in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# The histogram shows that there's a significant increase in Marvel movie releases, particularly from the early 2000s onwards, with a peak in recent years. There are also older entries, but the majority of the data points are concentrated in the modern era of filmmaking.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# This insight can help in understanding the growth trend of the Marvel cinematic universe over time. For businesses, this suggests that the market for Marvel-related content has expanded significantly in recent decades, indicating a growing audience and potential for new content or merchandise. There are no insights that lead to negative growth directly from this chart; rather, it indicates a sustained positive growth trajectory in movie production.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

plt.figure(figsize=(10, 6))
sns.histplot(df['year'], bins=20, kde=True)
plt.title('Distribution of Movie Release Years')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# A bar chart was chosen for displaying the top actors by movie count. This type of chart is ideal for comparing discrete categories (actor names) and their corresponding numerical values (number of movies). It provides a clear, at-a-glance view of the most frequently appearing actors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# The chart clearly identifies the actors who have appeared in the most Marvel movies. This highlights key recurring talent within the Marvel cinematic universe, indicating which actors are central to multiple storylines or franchises. There's a noticeable drop-off after the top few actors, suggesting a core group with many appearances and a larger group with fewer.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# This insight can significantly impact business decisions related to casting, marketing, and fan engagement. Identifying popular recurring actors can inform future casting choices, help in promotional strategies by leveraging well-known faces, and even guide merchandise development. Understanding which actors are most central to the franchise ensures continuity and maintains fan interest. There are no direct negative growth insights from this chart; instead, it reinforces the value of established talent.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

top_movies = df['title'].value_counts().head(10)
plt.figure(figsize=(10,6))
sns.barplot(x=top_movies.values,y=top_movies.index,palette='viridis')
plt.title("Top 10 Movies by Cast Size")
plt.xlabel("Number of Cast Members")
plt.ylabel("Movie")
plt.show()
# Out:
# /tmp/ipykernel_826/2084955102.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_movies.values,y=top_movies.index,palette='viridis')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

plt.figure(figsize=(10, 6))
sns.histplot(df['popularity'], bins=30, kde=True)
plt.title('Distribution of Actor Popularity')
plt.xlabel('Popularity Score')
plt.ylabel('Number of Actors')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram was chosen to display the distribution of actor popularity. This chart type is effective for showing the frequency of numerical data points within various bins, providing a clear visual of whether popularity scores are clustered or spread out, and identifying any peaks or skews in the data.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# The histogram of actor popularity reveals that a large number of actors have relatively low popularity scores, with a long tail extending towards higher popularity. This indicates that while there are many actors with moderate recognition, only a few achieve very high levels of popularity within the Marvel cast. There's a clear concentration of actors at the lower end of the popularity spectrum.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# Understanding the distribution of actor popularity can significantly impact business strategies. For casting decisions, it helps in identifying a pool of less popular (and potentially less expensive) talent versus high-demand, highly popular actors. In marketing, this insight can guide promotional efforts—whether to focus on the broad appeal of popular stars or to highlight emerging talent. There aren't direct negative growth insights, but a business might risk alienating fans if they solely focus on less popular actors without a compelling narrative, potentially leading to lower box office returns.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

plt.figure(figsize=(10, 6))
sns.scatterplot(x='cast_order', y='popularity', data=df, alpha=0.6)
plt.title('Actor Popularity vs. Cast Order')
plt.xlabel('Cast Order')
plt.ylabel('Popularity Score')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot was selected to visualize the relationship between `cast_order` and `popularity`. This chart is effective for displaying potential correlations or patterns between two numerical variables. It allows us to observe if there's any trend, such as higher popularity being associated with a lower cast order, or if the data points are widely dispersed, indicating little to no linear relationship.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# The scatter plot indicates a general trend where actors with lower `cast_order` values (meaning they are listed earlier in the cast credits) tend to have higher `popularity` scores. This is expected, as leading actors or those with more significant roles are typically listed first and are often more well-known. However, there's a wide spread of popularity scores even within lower cast orders, and some actors with higher cast orders still exhibit moderate popularity, suggesting that while cast order is a factor, it's not the sole determinant of an actor's popularity.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# This insight can be valuable for business impact in several ways. For production companies, understanding the correlation between cast order and popularity can help in strategic casting, marketing, and budgeting decisions. Focusing on actors with established popularity (often reflected in lower cast orders) can boost a film's marketability and potential box office success. Conversely, identifying promising actors with higher cast orders but growing popularity could represent cost-effective casting opportunities. This insight helps in optimizing resource allocation and maximizing return on investment by aligning casting strategies with market appeal. There are no direct negative growth insights from this chart, but misjudging the impact of cast order on popularity could lead to suboptimal casting or marketing efforts.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %%
top_actors = df['actor_name'].value_counts().head(15)
plt.figure(figsize=(10,6))
sns.barplot(x=top_actors.values,y=top_actors.index,palette='magma')
# Out:
# /tmp/ipykernel_826/1326854934.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_actors.values,y=top_actors.index,palette='magma')
# <Axes: ylabel='actor_name'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen to visualize the top 10 characters based on their average popularity. This chart type is effective for comparing the popularity scores across different discrete categories (character names) and quickly identifying the characters that, on average, have higher popularity.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that certain characters consistently have higher average popularity scores, even if they don't appear in the most movies. This suggests that some characters are inherently more appealing or have a stronger impact when they do appear, indicating their significance to the franchise beyond mere screen time or number of appearances. Interestingly, 'Self' or 'Self - Director' also appear, which might indicate that actors playing themselves or taking directorial roles often have high public recognition.

# %% [markdown]
# Answer Here

# %% [markdown]
# Understanding character popularity can guide content creation, spin-off development, and merchandise strategies. Focusing on characters with high inherent popularity can ensure fan engagement and potentially lead to successful new ventures. If 'Self' or 'Self - Director' characters appear with high popularity, it could mean that the behind-the-scenes figures or actors portraying themselves are also valuable assets for promotional activities. There are no direct negative growth insights, but misjudging the enduring appeal of a character could lead to missed opportunities in franchise expansion.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
avg_popularity_by_year = df.groupby('year')['popularity'].mean().reset_index()
plt.figure(figsize=(12, 7))
sns.lineplot(x='year', y='popularity', data=avg_popularity_by_year)
plt.title('Average Actor Popularity Over the Years')
plt.xlabel('Year')
plt.ylabel('Average Popularity Score')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# A line plot was chosen to display the average actor popularity over the years. This chart type is excellent for showing trends and changes in a numerical variable (`popularity`) over a continuous period (`year`), making it easy to identify any increase, decrease, or stability in actor popularity within the Marvel franchise over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# This chart would reveal if there's a general upward or downward trend in the average popularity of actors appearing in Marvel movies over the decades. It might show periods where the average popularity was lower (e.g., in earlier, less globally recognized productions) and periods where it surged (e.g., with the rise of the MCU). It could also highlight fluctuations, indicating shifts in casting strategies or broader public interest in certain types of actors.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Understanding the trend of actor popularity over time can have several business impacts. If average popularity is trending upwards, it indicates that the franchise is successfully attracting or developing more popular talent, which can be leveraged for marketing and audience engagement. If there are dips, it might prompt an analysis into why certain periods saw less popular actors, potentially leading to adjustments in casting or talent development strategies. This insight helps ensure the ongoing appeal and marketability of the franchise. There are no direct negative growth insights, but a sustained decline in average actor popularity could signal a need for strategic intervention to maintain audience interest.

# %%
# Chart - 8 visualization code

plt.title("Top 15 Actors")
plt.xlabel("Appearances")
plt.show()avg_popularity_by_character = df.groupby('character')['popularity'].mean().nlargest(10)
plt.figure(figsize=(12, 7))
sns.barplot(x=avg_popularity_by_character.values, y=avg_popularity_by_character.index, palette='magma')
plt.title('Top 10 Characters by Average Popularity')
plt.xlabel('Average Popularity Score')
plt.ylabel('Character Name')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
# Out:
#   File "/tmp/ipykernel_826/2124904922.py", line 5
#     plt.show()avg_popularity_by_character = df.groupby('character')['popularity'].mean().nlargest(10)
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# A scatter plot is chosen to visualize the relationship between `popularity` and `tmdb_id`. While `tmdb_id` is an identifier and not directly indicative of any quantifiable characteristic in this context, a scatter plot can help confirm that there's no inherent or spurious correlation between an actor's `tmdb_id` (which is typically assigned sequentially or arbitrarily) and their `popularity` score. This helps ensure that the `tmdb_id` is treated purely as an identifier and not misinterpreted as a measure of any underlying attribute that might influence popularity.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# This chart is primarily for sanity checking. We expect to see a scattered distribution with no clear pattern or correlation between `popularity` and `tmdb_id`. This confirms that the `tmdb_id`, as an arbitrary identifier, does not influence or reflect an actor's popularity. Any visible clusters or lines would be highly unusual and would warrant further investigation into data generation or potential errors.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# While not directly leading to positive growth, this insight provides crucial validation. By confirming that `tmdb_id` has no relationship with `popularity`, it prevents misinterpretations or the pursuit of non-existent patterns in the data, thus saving time and resources. It ensures that subsequent analyses correctly focus on truly relevant variables. A false positive correlation could lead to misguided business strategies, so this sanity check contributes to robust and reliable insights. There are no direct negative growth insights, but misunderstanding the nature of identifier variables could lead to flawed analysis and poor business decisions.

# %%
# Chart - 9 visualization code

plt.figure(figsize=(10, 6))
sns.histplot(df['cast_order'], bins=15, kde=False)
plt.title('Distribution of Cast Order')
plt.xlabel('Cast Order')
plt.ylabel('Number of Actors')
plt.xticks(range(0, df['cast_order'].max() + 1, 1))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# A histogram was chosen to visualize the distribution of `cast_order`. This chart type is ideal for understanding the frequency of each `cast_order` value, allowing us to see if there's a higher concentration of actors in leading roles (lower `cast_order` values) or supporting roles (higher `cast_order` values), and the overall spread of roles within the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# This chart would typically show that there are more actors in lower `cast_order` positions, indicating that most movies have a relatively small core cast and a larger number of supporting or minor roles. There might be a noticeable drop-off as the `cast_order` increases. This highlights the hierarchical nature of film casting, where a few actors take prominent roles, and many others fill smaller capacities.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Understanding the distribution of `cast_order` can help production houses and casting directors in resource allocation and budget planning. Knowing the typical structure of cast sizes can inform how many actors are needed for various roles and what their typical `cast_order` might be. This can optimize casting processes and manage expectations regarding the talent pool for different levels of roles. For example, a business can anticipate the need for a larger pool of actors for supporting roles. There are no direct negative growth insights, but misunderstanding this distribution could lead to inefficient casting calls or misallocation of budget if the typical number of roles at each `cast_order` level is not considered.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

top_actors = df['actor_name'].value_counts().head(10)
plt.figure(figsize=(12, 7))
sns.barplot(x=top_actors.values, y=top_actors.index, palette='viridis')
plt.title('Top 10 Actors by Number of Marvel Movies')
plt.xlabel('Number of Movies')
plt.ylabel('Actor Name')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

plt.figure(figsize=(10, 6))
sns.scatterplot(x='popularity', y='tmdb_id', data=df, alpha=0.6)
plt.title('Actor Popularity vs. TMDB ID')
plt.xlabel('Popularity Score')
plt.ylabel('TMDB ID')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

plt.figure(figsize=(8,4))
sns.boxplot(x=df['popularity'])
plt.title("Popularity Boxplot")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# A pie chart was chosen to visualize the distribution of `cast_order`. This chart type is effective for showing the proportion of each `cast_order` relative to the total number of cast entries. It clearly illustrates how the roles are distributed across different billing positions, from lead to supporting.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# The pie chart reveals the proportion of actors at each `cast_order` level. It likely shows that lower `cast_order` values (e.g., 0, 1, 2) which represent lead or prominent roles, account for a smaller percentage of the total cast, while higher `cast_order` values, representing supporting or minor roles, make up a larger proportion. This indicates that most actors in the dataset are in supporting capacities, which is typical for large ensemble films.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Understanding the distribution of `cast_order` can inform casting directors and producers about the typical structure of Marvel movie casts. This insight can help in budgeting and resource allocation for talent, ensuring that a sufficient pool of supporting actors is available while also identifying key lead roles. For marketing, it emphasizes the importance of a diverse ensemble cast, not just a few prominent stars. There are no direct negative growth insights, but an extreme imbalance (e.g., an unusually high percentage of lead roles for a film that typically relies on an ensemble) could signal a deviation from established successful casting patterns.

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

plt.figure(figsize=(12, 7))
sns.lineplot(x='year', y='unique_actors_count', data=unique_actors_per_year)
plt.title('Number of Unique Actors Appearing in Marvel Movies Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Unique Actors')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
numeric = df.select_dtypes(include=np.number)
plt.figure(figsize=(8,5))
sns.heatmap(numeric.corr(),annot=True,cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
